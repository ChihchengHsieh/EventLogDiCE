# %%
from parameters.dataset import BPI2012Parameters
from dataset import BPI2012Dataset
from parameters.enum import BPI2012ActivityType
from utils.bpi2012 import print_model_prediction_result, remove_tags_for_seq, get_example_data_with_removed_tail, generate_fake_df

# %%
dataset = BPI2012Dataset(BPI2012Parameters(
    include_complete_only=True,
    include_types=[BPI2012ActivityType.A, BPI2012ActivityType.O, BPI2012ActivityType.W],
))
# Out:
# ========================================
# | Preprocessed data loaded successfully: ./data/preprocessed/BPI_Challenge_2012_with_resource/AOW_CompleteOnly
# ========================================

# %%
# estimate how many features we will have.
all_activity_resource_combinations= []
for instance in dataset.df.iloc:
    for a, r in zip(instance["activity_vocab"], instance["resource_vocab"]):
        combination = f"{a}_{r}"
        if not (combination) in all_activity_resource_combinations:
            all_activity_resource_combinations.append(combination)

print(f"All {len(all_activity_resource_combinations)} combinations.")

## Too many combination. We better not doing this.
# Out:
# All 615 combinations.

# %%
# We don't need padding anymore.

# %%
trace_a = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
trace_b = ['a', 'e', 'h']

# %%
### Calculate distance for both trace.

# %%
# features.
new_count_df = []

for instance in dataset.df.iloc:
    count_map = {}
    for a in dataset.activity_vocab.vocabs:
        count_map[a] = instance.activity_vocab.count(a)

    new_count_df.append(count_map)
        # We count it.

# %%
import pandas as pd

# %%
pd.DataFrame(new_count_df)
# Out:
#        <PAD>  <EOS>  <SOS>  A_ACCEPTED_COMPLETE  A_ACTIVATED_COMPLETE  \
# 0          0      1      1                    1                     1
# 1          0      1      1                    1                     1
# 2          0      1      1                    1                     1
# 3          0      1      1                    0                     0
# 4          0      1      1                    0                     0
# ...      ...    ...    ...                  ...                   ...
# 13082      0      1      1                    1                     0
# 13083      0      1      1                    0                     0
# 13084      0      1      1                    0                     0
# 13085      0      1      1                    1                     0
# 13086      0      1      1                    0                     0
#
#        A_APPROVED_COMPLETE  A_CANCELLED_COMPLETE  A_DECLINED_COMPLETE  \
# 0                        1                     0                    0
# 1                        1                     0                    0
# 2                        1                     0                    0
# 3                        0                     0                    1
# 4                        0                     0                    1
# ...                    ...                   ...                  ...
# 13082                    0                     0                    0
# 13083                    0                     0                    1
# 13084                    0                     0                    1
# 13085                    0                     0                    0
# 13086                    0                     0                    1
#
#        A_FINALIZED_COMPLETE  A_PARTLYSUBMITTED_COMPLETE  ...  \
# 0                         1                           1  ...
# 1                         1                           1  ...
# 2                         1                           1  ...
# 3                         0                           1  ...
# 4                         0                           1  ...
# ...                     ...                         ...  ...
# 13082                     1                           1  ...
# 13083                     0                           1  ...
# 13084                     0                           1  ...
# 13085                     1                           1  ...
# 13086                     0                           1  ...
#
#        O_DECLINED_COMPLETE  O_SELECTED_COMPLETE  O_SENT_BACK_COMPLETE  \
# 0                        0                    1                     1
# 1                        0                    2                     1
# 2                        0                    3                     1
# 3                        0                    0                     0
# 4                        0                    0                     0
# ...                    ...                  ...                   ...
# 13082                    0                    2                     1
# 13083                    0                    0                     0
# 13084                    0                    0                     0
# 13085                    0                    1                     0
# 13086                    0                    0                     0
#
#        O_SENT_COMPLETE  W_Afhandelen leads_COMPLETE  \
# 0                    1                            0
# 1                    2                            0
# 2                    3                            0
# 3                    0                            0
# 4                    0                            0
# ...                ...                          ...
# 13082                2                            0
# 13083                0                            0
# 13084                0                            1
# 13085                1                            1
# 13086                0                            1
#
#        W_Beoordelen fraude_COMPLETE  W_Completeren aanvraag_COMPLETE  \
# 0                                 0                                1
# 1                                 0                                2
# 2                                 0                                4
# 3                                 0                                0
# 4                                 0                                0
# ...                             ...                              ...
# 13082                             0                                2
# 13083                             0                                0
# 13084                             0                                0
# 13085                             0                                1
# 13086                             0                                0
#
#        W_Nabellen incomplete dossiers_COMPLETE  W_Nabellen offertes_COMPLETE  \
# 0                                            0                             3
# 1                                            0                             4
# 2                                            0                            11
# 3                                            0                             0
# 4                                            0                             0
# ...                                        ...                           ...
# 13082                                        0                             4
# 13083                                        0                             0
# 13084                                        0                             0
# 13085                                        0                             1
# 13086                                        0                             0
#
#        W_Valideren aanvraag_COMPLETE
# 0                                  1
# 1                                  3
# 2                                  1
# 3                                  0
# 4                                  0
# ...                              ...
# 13082                              0
# 13083                              0
# 13084                              0
# 13085                              0
# 13086                              0
#
# [13087 rows x 26 columns]

# %%
dataset.activity_vocab.vocabs
# Out:
# ['<PAD>',
#  '<EOS>',
#  '<SOS>',
#  'A_ACCEPTED_COMPLETE',
#  'A_ACTIVATED_COMPLETE',
#  'A_APPROVED_COMPLETE',
#  'A_CANCELLED_COMPLETE',
#  'A_DECLINED_COMPLETE',
#  'A_FINALIZED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'A_PREACCEPTED_COMPLETE',
#  'A_REGISTERED_COMPLETE',
#  'A_SUBMITTED_COMPLETE',
#  'O_ACCEPTED_COMPLETE',
#  'O_CANCELLED_COMPLETE',
#  'O_CREATED_COMPLETE',
#  'O_DECLINED_COMPLETE',
#  'O_SELECTED_COMPLETE',
#  'O_SENT_BACK_COMPLETE',
#  'O_SENT_COMPLETE',
#  'W_Afhandelen leads_COMPLETE',
#  'W_Beoordelen fraude_COMPLETE',
#  'W_Completeren aanvraag_COMPLETE',
#  'W_Nabellen incomplete dossiers_COMPLETE',
#  'W_Nabellen offertes_COMPLETE',
#  'W_Valideren aanvraag_COMPLETE']

# %%
# from above cell we know W can be in 6 positions.

# What's last A milestones

W_activities = [
    'W_Afhandelen leads_COMPLETE',
    'W_Beoordelen fraude_COMPLETE',
    'W_Completeren aanvraag_COMPLETE',
    'W_Nabellen incomplete dossiers_COMPLETE',
    'W_Nabellen offertes_COMPLETE',
    'W_Valideren aanvraag_COMPLETE'
]

A_activities = [
    'A_ACCEPTED_COMPLETE',
    'A_ACTIVATED_COMPLETE',
    'A_APPROVED_COMPLETE',
    'A_CANCELLED_COMPLETE',
    'A_DECLINED_COMPLETE',
    'A_FINALIZED_COMPLETE',
    'A_PARTLYSUBMITTED_COMPLETE',
    'A_PREACCEPTED_COMPLETE',
    'A_REGISTERED_COMPLETE',
]

W_position_map = {}
# Initialise W map

for w_a in W_activities:
    W_position_map[w_a] = []
    # The element should be start_end. And we only consider "A"


for instance in dataset.df.iloc:
    instance_activities = instance["activity_vocab"]
    for idx, a in enumerate(instance_activities):
        if a.startswith("W_"):
            # I have to check the starting milestone.
            for start in instance_activities[0: idx][::-1]:
                if start.startswith("A_"):
                    starting_A = start
                    break

            # Ending milestone
            for end in instance_activities[idx+1:]:
                if end.startswith("A_"):
                    ending_A = end
                    break

            inMiddleOf = f"{starting_A}_&_{ending_A}"
            
            if not ( inMiddleOf in W_position_map[a]):
                W_position_map[a].append(inMiddleOf)

# %%
W_position_map # Just count the existance count.
# Out:
# {'W_Afhandelen leads_COMPLETE': ['A_PREACCEPTED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_PARTLYSUBMITTED_COMPLETE_&_A_PREACCEPTED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_PARTLYSUBMITTED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_PARTLYSUBMITTED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_PREACCEPTED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_FINALIZED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_PREACCEPTED_COMPLETE'],
#  'W_Beoordelen fraude_COMPLETE': ['A_PREACCEPTED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_PARTLYSUBMITTED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_PARTLYSUBMITTED_COMPLETE_&_A_PREACCEPTED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_APPROVED_COMPLETE'],
#  'W_Completeren aanvraag_COMPLETE': ['A_FINALIZED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_ACCEPTED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_ACCEPTED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_ACCEPTED_COMPLETE_&_A_FINALIZED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_PREACCEPTED_COMPLETE_&_A_PREACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_FINALIZED_COMPLETE',
#   'A_ACCEPTED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_PREACCEPTED_COMPLETE'],
#  'W_Nabellen incomplete dossiers_COMPLETE': ['A_FINALIZED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_ACTIVATED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_REGISTERED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_REGISTERED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_APPROVED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_ACTIVATED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_APPROVED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_FINALIZED_COMPLETE'],
#  'W_Nabellen offertes_COMPLETE': ['A_FINALIZED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_ACTIVATED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_FINALIZED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_PREACCEPTED_COMPLETE'],
#  'W_Valideren aanvraag_COMPLETE': ['A_ACTIVATED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_REGISTERED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_ACTIVATED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_DECLINED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_DECLINED_COMPLETE',
#   'A_APPROVED_COMPLETE_&_A_ACTIVATED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_APPROVED_COMPLETE_&_A_REGISTERED_COMPLETE',
#   'A_REGISTERED_COMPLETE_&_A_APPROVED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_CANCELLED_COMPLETE_&_A_CANCELLED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_ACCEPTED_COMPLETE',
#   'A_FINALIZED_COMPLETE_&_A_FINALIZED_COMPLETE']}

# %%
[1, 2,3,4,5,6][0:][::-1]
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
milestones=[
        "A_SUBMITTED_COMPLETE",
        "A_PARTLYSUBMITTED_COMPLETE",
        "A_PREACCEPTED_COMPLETE",
        "A_ACCEPTED_COMPLETE",
        "A_FINALIZED_COMPLETE",
        # "O_SELECTED_COMPLETE",
        # "O_CREATED_COMPLETE",
        # "O_SENT_COMPLETE",
        # "O_SENT_BACK_COMPLETE",
        "A_APPROVED_COMPLETE",
        "A_ACTIVATED_COMPLETE",
        "A_REGISTERED_COMPLETE",
    ]

### Check that all milestones will not repeat

# %%
for instance in dataset.df.iloc:
    for m in milestones:
        if instance["activity_vocab"].count(m) > 1:
            print(m)
            print("============")
            print(instance["activity_vocab"])
            print("============")
            print(instance["activitay_vocab"].count(m))
            raise StopIteration

## All the A instance will not repeat.
## So we have to check what's the last instance of A.

### Question:
## For resource, how we manage it?
## 1. It has too much comination so we can't make it a categorical data.
## 2. If we don't use resource. We lost some of the information that may help us.
## But how can we use resource here.
## Resource is highly related to the activity.
## Let's see what each resource can do
## 3.

# %%
# what each resource can do
resource_do_activity = {}
for instance in dataset.df.iloc:
    for a, r in zip(instance["activity_vocab"], instance["resource_vocab"]):
        if not (r in resource_do_activity.keys()):
            resource_do_activity[r] = []

        if not (a in resource_do_activity[r]):
            resource_do_activity[r].append(a)

# %%
## Each resource can do.
import numpy as np
print(np.mean([len(v) for v in resource_do_activity.values()]))
# Out:
# 12.366197183098592

# %%
dataset.df
# Out:
#                                                 activity  \
# 0      [2, 12, 9, 10, 3, 17, 8, 15, 19, 22, 24, 24, 1...
# 1      [2, 12, 9, 10, 22, 3, 8, 17, 15, 19, 22, 24, 1...
# 2      [2, 12, 9, 10, 22, 22, 22, 3, 17, 8, 15, 19, 2...
# 3                                       [2, 12, 9, 7, 1]
# 4                                       [2, 12, 9, 7, 1]
# ...                                                  ...
# 13082  [2, 12, 9, 10, 22, 3, 8, 17, 15, 19, 22, 17, 1...
# 13083                                   [2, 12, 9, 7, 1]
# 13084                               [2, 12, 9, 7, 20, 1]
# 13085    [2, 12, 9, 10, 20, 3, 17, 8, 15, 19, 22, 24, 1]
# 13086                               [2, 12, 9, 7, 20, 1]
#
#                                           activity_vocab  caseid   amount  \
# 0      [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  173688  20000.0
# 1      [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  173691   5000.0
# 2      [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  173694   7000.0
# 3      [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  173697  15000.0
# 4      [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  173700   5000.0
# ...                                                  ...     ...      ...
# 13082  [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  214364   5000.0
# 13083  [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  214367    500.0
# 13084  [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  214370  20000.0
# 13085  [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  214373   8500.0
# 13086  [<SOS>, A_SUBMITTED_COMPLETE, A_PARTLYSUBMITTE...  214376  15000.0
#
#                                                 resource  \
# 0      [70, 53, 53, 53, 14, 14, 14, 14, 14, 71, 71, 2...
# 1      [70, 53, 53, 53, 71, 14, 14, 14, 14, 14, 71, 7...
# 2      [70, 53, 53, 53, 22, 71, 55, 55, 55, 55, 55, 5...
# 3                                   [70, 53, 53, 53, 69]
# 4                                   [70, 53, 53, 53, 69]
# ...                                                  ...
# 13082  [70, 53, 53, 53, 48, 37, 37, 37, 37, 37, 37, 3...
# 13083                               [70, 53, 53, 53, 69]
# 13084                           [70, 53, 53, 48, 48, 69]
# 13085  [70, 53, 53, 48, 48, 28, 28, 28, 28, 28, 28, 4...
# 13086                           [70, 53, 53, 48, 48, 69]
#
#                                           resource_vocab
# 0      [<SOS>, 112, 112, 112, 10862, 10862, 10862, 10...
# 1      [<SOS>, 112, 112, 112, UNKNOWN, 10862, 10862, ...
# 2      [<SOS>, 112, 112, 112, 10912, UNKNOWN, 11201, ...
# 3                          [<SOS>, 112, 112, 112, <EOS>]
# 4                          [<SOS>, 112, 112, 112, <EOS>]
# ...                                                  ...
# 13082  [<SOS>, 112, 112, 112, 11169, 11003, 11003, 11...
# 13083                      [<SOS>, 112, 112, 112, <EOS>]
# 13084             [<SOS>, 112, 112, 11169, 11169, <EOS>]
# 13085  [<SOS>, 112, 112, 11169, 11169, 10933, 10933, ...
# 13086             [<SOS>, 112, 112, 11169, 11169, <EOS>]
#
# [13087 rows x 6 columns]

# %%
# Out:
# False

# %%
dataset.activity_vocab.vocabs
# Out:
# ['<PAD>',
#  '<EOS>',
#  '<SOS>',
#  'A_ACCEPTED_COMPLETE',
#  'A_ACTIVATED_COMPLETE',
#  'A_APPROVED_COMPLETE',
#  'A_CANCELLED_COMPLETE',
#  'A_DECLINED_COMPLETE',
#  'A_FINALIZED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'A_PREACCEPTED_COMPLETE',
#  'A_REGISTERED_COMPLETE',
#  'A_SUBMITTED_COMPLETE',
#  'O_ACCEPTED_COMPLETE',
#  'O_CANCELLED_COMPLETE',
#  'O_CREATED_COMPLETE',
#  'O_DECLINED_COMPLETE',
#  'O_SELECTED_COMPLETE',
#  'O_SENT_BACK_COMPLETE',
#  'O_SENT_COMPLETE',
#  'W_Afhandelen leads_COMPLETE',
#  'W_Beoordelen fraude_COMPLETE',
#  'W_Completeren aanvraag_COMPLETE',
#  'W_Nabellen incomplete dossiers_COMPLETE',
#  'W_Nabellen offertes_COMPLETE',
#  'W_Valideren aanvraag_COMPLETE']

# %%
print("The activity that everyone have")
for v in dataset.activity_vocab.vocabs:
    if len((dataset.df[dataset.df['activity_vocab'].apply(
        lambda a: v in a)])) == len(dataset.df):
        print(v)
# Out:
# <EOS>
# <SOS>
# A_PARTLYSUBMITTED_COMPLETE
# A_SUBMITTED_COMPLETE

# %%
len(dataset.resource_vocab.vocabs) # We got 72 different resource
# Out:
# 72

# %%
(
    example_vocab_activities,
    example_idx_activities,
    example_vocab_resources,
    example_idx_resources,
    example_amount,
    ground_truth_vocab
) = get_example_data_with_removed_tail(
    dataset,
    trace_idx=52,
    tail_length_to_remove=4
)
# Out:
# ====================Activity====================
# | [['<SOS>', 'A_SUBMITTED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'A_ACCEPTED_COMPLETE', 'A_FINALIZED_COMPLETE', 'O_SELECTED_COMPLETE', 'O_CREATED_COMPLETE', 'O_SENT_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'O_SENT_BACK_COMPLETE', 'W_Nabellen offertes_COMPLETE', 'O_ACCEPTED_COMPLETE', 'A_APPROVED_COMPLETE', 'A_REGISTERED_COMPLETE', 'A_ACTIVATED_COMPLETE', 'W_Valideren aanvraag_COMPLETE']]
# ================================================
#
# ====================Resource====================
# | [['<SOS>', '112', '112', '112', '11180', '11201', '11201', '11201', '11201', '11201', '11201', '11201', '11049', '11049', '10629', '10629', '10629', '10629', '10629']]
# ================================================
#
# ====================Amount====================
# | [15500.0]
# ==============================================
#
# ====================Activity (Tail removed)====================
# | ['<SOS>', 'A_SUBMITTED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'A_ACCEPTED_COMPLETE', 'A_FINALIZED_COMPLETE', 'O_SELECTED_COMPLETE', 'O_CREATED_COMPLETE', 'O_SENT_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'O_SENT_BACK_COMPLETE', 'W_Nabellen offertes_COMPLETE', 'O_ACCEPTED_COMPLETE']
# ===============================================================
#
# ====================Resource (Tail removed)====================
# | ['<SOS>', '112', '112', '112', '11180', '11201', '11201', '11201', '11201', '11201', '11201', '11201', '11049', '11049', '10629']
# ===============================================================
#
# ====================Ground Truth====================
# | A_APPROVED_COMPLETE
# ====================================================
