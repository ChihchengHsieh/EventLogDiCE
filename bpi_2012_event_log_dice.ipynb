# %%
from parameters.dataset import BPI2012Parameters
from dataset import BPI2012Dataset
from utils.print import print_block
from utils.bpi2012 import remove_trail_steps, print_model_prediction_result, remove_tags_for_seq
import tensorflow as tf
from model import LSTMPredNextModel, LSTMScenarioCfModel
import numpy as np
from dice import EventLogDiCE

# %%
dataset = BPI2012Dataset(BPI2012Parameters())
# Out:
# ========================================
# | Preprocessed data loaded successfully: ./data/preprocessed/BPI_Challenge_2012_with_resource/AOW_CompleteOnly
# ========================================

# %%
trace_idx = 52
_, example_activities, _, example_resources, example_amount, _ = dataset.collate_fn([trace_idx])
print_block(dataset.activity_vocab.list_of_index_to_vocab_2d(example_activities),"Activity")
print_block(dataset.resource_vocab.list_of_index_to_vocab_2d(example_resources),"Resource")
# Out:
# ====================Activity====================
# | [['<SOS>', 'A_SUBMITTED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'A_ACCEPTED_COMPLETE', 'A_FINALIZED_COMPLETE', 'O_SELECTED_COMPLETE', 'O_CREATED_COMPLETE', 'O_SENT_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'O_SENT_BACK_COMPLETE', 'W_Nabellen offertes_COMPLETE', 'O_ACCEPTED_COMPLETE', 'A_APPROVED_COMPLETE', 'A_REGISTERED_COMPLETE', 'A_ACTIVATED_COMPLETE', 'W_Valideren aanvraag_COMPLETE']]
# ================================================
#
# ====================Resource====================
# | [['<SOS>', '112', '112', '112', '11180', '11201', '11201', '11201', '11201', '11201', '11201', '11201', '11049', '11049', '10629', '10629', '10629', '10629', '10629']]
# ================================================

# %%
## Remove tails
tail_length_to_remove = 12
example_idx_activities, example_idx_resources = remove_trail_steps(example_activities, example_resources, tail_length_to_remove)
example_vocab_activities = dataset.activity_vocab.list_of_index_to_vocab_2d(example_idx_activities)[0]
example_vocab_resources = dataset.resource_vocab.list_of_index_to_vocab_2d(example_idx_resources)[0]
print_block(example_vocab_activities, "Activity (Tail removed)")
print_block(example_vocab_resources, "Resource (Tail removed)")
# Out:
# ====================Activity (Tail removed)====================
# | ['<SOS>', 'A_SUBMITTED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'A_ACCEPTED_COMPLETE']
# ===============================================================
#
# ====================Resource (Tail removed)====================
# | ['<SOS>', '112', '112', '112', '11180', '11201', '11201']
# ===============================================================

# %%
pred_model = LSTMPredNextModel.load(
    "./SavedModels/%s" % (
    "0.8175_LSTMPredNextModel_AOW_CompleteOnly_2021-07-01 20:45:16.353467" 
    )
)
# Out:
# ========================================
# | Model parameters loaded successfully from: ./SavedModels/0.8175_LSTMPredNextModel_AOW_CompleteOnly_2021-07-01 20:45:16.353467
# ========================================
#
# ========================================
# | Vocab loaded successfully from: ./SavedModels/0.8175_LSTMPredNextModel_AOW_CompleteOnly_2021-07-01 20:45:16.353467
# ========================================
#
# ========================================
# | Model loaded successfully from: ./SavedModels/0.8175_LSTMPredNextModel_AOW_CompleteOnly_2021-07-01 20:45:16.353467
# ========================================

# %%
_ = pred_model(**pred_model.get_example_input())
pred_model.summary()
# Out:
# Model: "LSTMPredNextModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  832
# _________________________________________________________________
# embedding_1 (Embedding)      multiple                  9216
# _________________________________________________________________
# lstm (LSTM)                  multiple                  24832
# _________________________________________________________________
# lstm_1 (LSTM)                multiple                  33024
# _________________________________________________________________
# lstm_2 (LSTM)                multiple                  49408
# _________________________________________________________________
# lstm_3 (LSTM)                multiple                  33024
# _________________________________________________________________
# sequential (Sequential)      (1, 64)                   4544
# _________________________________________________________________
# sequential_1 (Sequential)    (1, 1, 26)                15066
# =================================================================
# Total params: 169,946
# Trainable params: 169,306
# Non-trainable params: 640
# _________________________________________________________________

# %%
##### Get model output
example_activities_input = tf.constant(example_idx_activities)
example_resources_input = tf.constant(example_idx_resources)
example_amount_input = tf.constant(example_amount)

predicted_df = print_model_prediction_result(pred_model, example_activities_input, example_resources_input, example_amount_input)
# Out:
# ========================================Predict result========================================
# | Predicted activity with highest probability (0.52) is "O_SELECTED_COMPLETE"
# ==============================================================================================
#
#
#
# <PAD>                                      2.067023e-06
# <EOS>                                      7.659809e-07
# <SOS>                                      8.025153e-07
# A_ACCEPTED_COMPLETE                        7.223138e-05
# A_ACTIVATED_COMPLETE                       1.524770e-05
# A_APPROVED_COMPLETE                        1.436770e-08
# A_CANCELLED_COMPLETE                       2.858025e-03
# A_DECLINED_COMPLETE                        1.595676e-04
# A_FINALIZED_COMPLETE                       4.776102e-01
# A_PARTLYSUBMITTED_COMPLETE                 3.203258e-08
# A_PREACCEPTED_COMPLETE                     2.379254e-07
# A_REGISTERED_COMPLETE                      3.801360e-05
# A_SUBMITTED_COMPLETE                       6.117714e-06
# O_ACCEPTED_COMPLETE                        4.300811e-06
# O_CANCELLED_COMPLETE                       3.748707e-06
# O_CREATED_COMPLETE                         1.539560e-05
# O_DECLINED_COMPLETE                        2.835283e-06
# O_SELECTED_COMPLETE                        5.166543e-01
# O_SENT_BACK_COMPLETE                       2.728928e-06
# O_SENT_COMPLETE                            1.770205e-06
# W_Afhandelen leads_COMPLETE                9.524249e-08
# W_Beoordelen fraude_COMPLETE               9.414581e-08
# W_Completeren aanvraag_COMPLETE            2.549386e-03
# W_Nabellen incomplete dossiers_COMPLETE    8.750534e-08
# W_Nabellen offertes_COMPLETE               8.449899e-07
# W_Valideren aanvraag_COMPLETE              9.751826e-07
# Name: 0, dtype: float64

# %%
predicted_df
# Out:
#       <PAD>         <EOS>         <SOS>  A_ACCEPTED_COMPLETE  \
# 0  0.000002  7.659809e-07  8.025153e-07             0.000072
#
#    A_ACTIVATED_COMPLETE  A_APPROVED_COMPLETE  A_CANCELLED_COMPLETE  \
# 0              0.000015         1.436770e-08              0.002858
#
#    A_DECLINED_COMPLETE  A_FINALIZED_COMPLETE  A_PARTLYSUBMITTED_COMPLETE  ...  \
# 0              0.00016               0.47761                3.203258e-08  ...
#
#    O_DECLINED_COMPLETE  O_SELECTED_COMPLETE  O_SENT_BACK_COMPLETE  \
# 0             0.000003             0.516654              0.000003
#
#    O_SENT_COMPLETE  W_Afhandelen leads_COMPLETE  W_Beoordelen fraude_COMPLETE  \
# 0         0.000002                 9.524249e-08                  9.414581e-08
#
#    W_Completeren aanvraag_COMPLETE  W_Nabellen incomplete dossiers_COMPLETE  \
# 0                         0.002549                             8.750534e-08
#
#    W_Nabellen offertes_COMPLETE  W_Valideren aanvraag_COMPLETE
# 0                  8.449899e-07                   9.751826e-07
#
# [1 rows x 26 columns]

# %%
no_need_tags = ['<EOS>', '<SOS>', '<PAD>']

possible_activities = [ a for a in list(pred_model.activity_vocab.vocabs) if  not a in no_need_tags]
possible_resources =  [ r for r in list(pred_model.resource_vocab.vocabs) if  not r in no_need_tags]

example_vocab_activities_no_tag = remove_tags_for_seq(example_vocab_activities, no_need_tags)

example_vocab_resources_no_tag = remove_tags_for_seq(example_vocab_resources, no_need_tags)

# transform to possible dim
example_idx_activities_no_tag = [ possible_activities.index(v)   for v in example_vocab_activities_no_tag ]

example_idx_resources_no_tag = [
possible_resources.index(v)   for v in example_vocab_resources_no_tag    
]

example_trace_len_no_tag = len(example_vocab_activities_no_tag)
#### Determine feature names for DiCE ####
activity_feature_names = np.array(["activity_step_%d" % (i+1) for i in range(example_trace_len_no_tag)])
resource_feature_names = np.array(["resource_step_%d" % (i+1) for i in range(example_trace_len_no_tag)])
possbile_amount = [min(dataset.df["amount"]), max(dataset.df["amount"])]

print_block(example_vocab_activities_no_tag ,title="Example activities without tags", num_marks = 30)
print_block(example_vocab_resources_no_tag ,title="Example resources without tags", num_marks = 30)
print_block(example_amount, title="=================Amount=================", num_marks=16)
# Out:
# ==============================Example activities without tags==============================
# | ['A_SUBMITTED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'A_ACCEPTED_COMPLETE']
# ===========================================================================================
#
# ==============================Example resources without tags==============================
# | ['112', '112', '112', '11180', '11201', '11201']
# ==========================================================================================
#
# =================================Amount=================================
# | [15500.0]
# ========================================================================

# %%
scenario_model = LSTMScenarioCfModel.load(
    "./SavedModels/%s" % (
        "0.9857_LSTMScenarioCfModel_AOW_CompleteOnly_20_times_2021-07-01 23:50:36.530541" 
    )
)
# Out:
# ========================================
# | Model parameters loaded successfully from: ./SavedModels/0.9857_LSTMScenarioCfModel_AOW_CompleteOnly_20_times_2021-07-01 23:50:36.530541
# ========================================
#
# ========================================
# | Vocab loaded successfully from: ./SavedModels/0.9857_LSTMScenarioCfModel_AOW_CompleteOnly_20_times_2021-07-01 23:50:36.530541
# ========================================
#
# ========================================
# | Model loaded successfully from: ./SavedModels/0.9857_LSTMScenarioCfModel_AOW_CompleteOnly_20_times_2021-07-01 23:50:36.530541
# ========================================

# %%
_ = scenario_model(**scenario_model.get_example_input())
scenario_model.summary()
# Out:
# Model: "LSTMScenarioCfModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      multiple                  832
# _________________________________________________________________
# embedding_3 (Embedding)      multiple                  9216
# _________________________________________________________________
# lstm_4 (LSTM)                multiple                  24832
# _________________________________________________________________
# lstm_5 (LSTM)                multiple                  33024
# _________________________________________________________________
# lstm_6 (LSTM)                multiple                  49408
# _________________________________________________________________
# lstm_7 (LSTM)                multiple                  33024
# _________________________________________________________________
# sequential_2 (Sequential)    (1, 1, 1)                 9157
# =================================================================
# Total params: 159,493
# Trainable params: 159,107
# Non-trainable params: 386
# _________________________________________________________________

# %%
dice = EventLogDiCE(
    dataset.activity_vocab,
    dataset.resource_vocab,
    possbile_amount,
    possible_activities,
    possible_resources, 
    pred_model,
    scenario_model
    )

# %%
cf_out = dice.run_pls(
    ## Input
    example_amount_input.numpy(),
    example_idx_activities_no_tag,
    example_idx_resources_no_tag,
    desired_vocab = "A_DECLINED_COMPLETE",
    
    ## Weight
    class_loss_weight = 1,
    scenario_weight = 200,
    distance_loss_weight = 1e-8,
    cat_loss_weight = 1e-3,
    
    ## Training parameters
    scenario_threshold = 0.3,
    scenario_ask_to_continue=True,
    max_iter=2000,
    lr=0.5,

    ## Updating fields
    # updating_amount_cf=False,
    # updating_activity_cf=False,
    # updating_resource_cf=False,
    
    ## Options
    use_valid_cf_only=False,
    use_sampling=True,
    class_using_hinge_loss=False,
    scenario_using_hinge_loss=False,
    use_clipping=True, 
)
# Out:
# Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1100 Loss====================
# | Total [3373.69] | Scenario [16.82] | Class [2.20] | Category [7299.49] | Distance [302734.72]
# ======================================================
#
# ====================Step 1100 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1120 Loss====================
# | Total [3373.02] | Scenario [16.82] | Class [2.20] | Category [7299.49] | Distance [313834.72]
# ======================================================
#
# ====================Step 1120 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1140 Loss====================
# | Total [3372.35] | Scenario [16.81] | Class [2.20] | Category [7299.49] | Distance [325134.72]
# ======================================================
#
# ====================Step 1140 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1160 Loss====================
# | Total [3371.67] | Scenario [16.81] | Class [2.20] | Category [7299.49] | Distance [336634.72]
# ======================================================
#
# ====================Step 1160 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1180 Loss====================
# | Total [3371.01] | Scenario [16.81] | Class [2.20] | Category [7299.49] | Distance [348334.72]
# ======================================================
#
# ====================Step 1180 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1200 Loss====================
# | Total [3370.33] | Scenario [16.80] | Class [2.20] | Category [7299.49] | Distance [360234.72]
# ======================================================
#
# ====================Step 1200 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1220 Loss====================
# | Total [3369.66] | Scenario [16.80] | Class [2.20] | Category [7299.49] | Distance [372334.72]
# ======================================================
#
# ====================Step 1220 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1240 Loss====================
# | Total [3368.99] | Scenario [16.80] | Class [2.20] | Category [7299.49] | Distance [384634.72]
# ======================================================
#
# ====================Step 1240 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1260 Loss====================
# | Total [3368.32] | Scenario [16.79] | Class [2.20] | Category [7299.49] | Distance [397134.72]
# ======================================================
#
# ====================Step 1260 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1280 Loss====================
# | Total [3367.65] | Scenario [16.79] | Class [2.20] | Category [7299.50] | Distance [409834.72]
# ======================================================
#
# ====================Step 1280 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1300 Loss====================
# | Total [3366.98] | Scenario [16.79] | Class [2.20] | Category [7299.50] | Distance [422734.72]
# ======================================================
#
# ====================Step 1300 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1320 Loss====================
# | Total [3366.31] | Scenario [16.78] | Class [2.20] | Category [7299.50] | Distance [435834.72]
# ======================================================
#
# ====================Step 1320 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1340 Loss====================
# | Total [3365.64] | Scenario [16.78] | Class [2.20] | Category [7299.51] | Distance [449134.72]
# ======================================================
#
# ====================Step 1340 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1360 Loss====================
# | Total [3364.97] | Scenario [16.78] | Class [2.20] | Category [7299.51] | Distance [462634.72]
# ======================================================
#
# ====================Step 1360 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1380 Loss====================
# | Total [3364.31] | Scenario [16.77] | Class [2.20] | Category [7299.52] | Distance [476334.72]
# ======================================================
#
# ====================Step 1380 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1400 Loss====================
# | Total [3363.65] | Scenario [16.77] | Class [2.20] | Category [7299.52] | Distance [490234.72]
# ======================================================
#
# ====================Step 1400 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1420 Loss====================
# | Total [3362.98] | Scenario [16.77] | Class [2.20] | Category [7299.52] | Distance [504334.72]
# ======================================================
#
# ====================Step 1420 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1440 Loss====================
# | Total [3362.31] | Scenario [16.76] | Class [2.20] | Category [7299.53] | Distance [518634.72]
# ======================================================
#
# ====================Step 1440 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1460 Loss====================
# | Total [3361.64] | Scenario [16.76] | Class [2.20] | Category [7299.53] | Distance [533134.75]
# ======================================================
#
# ====================Step 1460 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1480 Loss====================
# | Total [3360.97] | Scenario [16.76] | Class [2.20] | Category [7299.54] | Distance [547834.75]
# ======================================================
#
# ====================Step 1480 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1500 Loss====================
# | Total [3360.29] | Scenario [16.75] | Class [2.20] | Category [7299.54] | Distance [562734.75]
# ======================================================
#
# ====================Step 1500 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1520 Loss====================
# | Total [3359.61] | Scenario [16.75] | Class [2.20] | Category [7299.55] | Distance [577834.75]
# ======================================================
#
# ====================Step 1520 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1540 Loss====================
# | Total [3358.94] | Scenario [16.75] | Class [2.20] | Category [7299.55] | Distance [593134.75]
# ======================================================
#
# ====================Step 1540 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1560 Loss====================
# | Total [3358.26] | Scenario [16.74] | Class [2.20] | Category [7299.56] | Distance [608634.75]
# ======================================================
#
# ====================Step 1560 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1580 Loss====================
# | Total [3357.59] | Scenario [16.74] | Class [2.20] | Category [7299.57] | Distance [624334.75]
# ======================================================
#
# ====================Step 1580 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1600 Loss====================
# | Total [3356.93] | Scenario [16.74] | Class [2.20] | Category [7299.57] | Distance [640234.75]
# ======================================================
#
# ====================Step 1600 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1620 Loss====================
# | Total [3356.27] | Scenario [16.73] | Class [2.20] | Category [7299.58] | Distance [656334.75]
# ======================================================
#
# ====================Step 1620 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1640 Loss====================
# | Total [3355.63] | Scenario [16.73] | Class [2.20] | Category [7299.59] | Distance [672634.75]
# ======================================================
#
# ====================Step 1640 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1660 Loss====================
# | Total [3354.98] | Scenario [16.73] | Class [2.20] | Category [7299.60] | Distance [689134.75]
# ======================================================
#
# ====================Step 1660 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1680 Loss====================
# | Total [3354.33] | Scenario [16.72] | Class [2.20] | Category [7299.60] | Distance [705834.75]
# ======================================================
#
# ====================Step 1680 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1700 Loss====================
# | Total [3353.68] | Scenario [16.72] | Class [2.20] | Category [7299.61] | Distance [722734.75]
# ======================================================
#
# ====================Step 1700 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1720 Loss====================
# | Total [3353.02] | Scenario [16.72] | Class [2.20] | Category [7299.61] | Distance [739834.75]
# ======================================================
#
# ====================Step 1720 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1740 Loss====================
# | Total [3352.35] | Scenario [16.71] | Class [2.20] | Category [7299.62] | Distance [757134.75]
# ======================================================
#
# ====================Step 1740 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1760 Loss====================
# | Total [3351.69] | Scenario [16.71] | Class [2.20] | Category [7299.62] | Distance [774634.75]
# ======================================================
#
# ====================Step 1760 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1780 Loss====================
# | Total [3351.03] | Scenario [16.71] | Class [2.20] | Category [7299.63] | Distance [792334.75]
# ======================================================
#
# ====================Step 1780 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1800 Loss====================
# | Total [3350.37] | Scenario [16.70] | Class [2.20] | Category [7299.63] | Distance [810234.75]
# ======================================================
#
# ====================Step 1800 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1820 Loss====================
# | Total [3349.71] | Scenario [16.70] | Class [2.20] | Category [7299.63] | Distance [828334.75]
# ======================================================
#
# ====================Step 1820 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1840 Loss====================
# | Total [3349.05] | Scenario [16.70] | Class [2.20] | Category [7299.63] | Distance [846634.75]
# ======================================================
#
# ====================Step 1840 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1860 Loss====================
# | Total [3348.38] | Scenario [16.69] | Class [2.20] | Category [7299.63] | Distance [865134.75]
# ======================================================
#
# ====================Step 1860 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1880 Loss====================
# | Total [3347.72] | Scenario [16.69] | Class [2.20] | Category [7299.63] | Distance [883834.75]
# ======================================================
#
# ====================Step 1880 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1900 Loss====================
# | Total [3347.06] | Scenario [16.69] | Class [2.20] | Category [7299.63] | Distance [902734.75]
# ======================================================
#
# ====================Step 1900 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1920 Loss====================
# | Total [3346.40] | Scenario [16.68] | Class [2.20] | Category [7299.63] | Distance [921834.75]
# ======================================================
#
# ====================Step 1920 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1940 Loss====================
# | Total [3345.75] | Scenario [16.68] | Class [2.20] | Category [7299.63] | Distance [941134.75]
# ======================================================
#
# ====================Step 1940 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1960 Loss====================
# | Total [3345.09] | Scenario [16.68] | Class [2.20] | Category [7299.62] | Distance [960634.75]
# ======================================================
#
# ====================Step 1960 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ====================Step 1980 Loss====================
# | Total [3344.44] | Scenario [16.67] | Class [2.20] | Category [7299.61] | Distance [980334.75]
# ======================================================
#
# ====================Step 1980 CF predicted====================
# | Invalid: A_PARTLYSUBMITTED_COMPLETE (9) | Valid: A_SUBMITTED_COMPLETE (12)
# ==============================================================
#
# ========================================
# | No valid counterfactual found! 😰
# ========================================
#
# ====================Input Amount====================
# | [15500.]
# ====================================================
#
# ====================Input Activities====================
# | ['A_SUBMITTED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'A_ACCEPTED_COMPLETE']
# ========================================================
#
# ====================Input Resource====================
# | ['112', '112', '112', '11180', '11201', '11201']
# ======================================================
#
# ====================Current CF Amount====================
# | 14500.0
# =========================================================
#
# ====================Current CF Activities====================
# | ['A_ACCEPTED_COMPLETE', 'A_ACCEPTED_COMPLETE', 'A_ACCEPTED_COMPLETE', 'A_ACCEPTED_COMPLETE', 'A_FINALIZED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE']
# =============================================================
#
# ====================Current CF Resource====================
# | ['10124', '10124', '10124', '10124', '10124', '10124']
# ===========================================================
